# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroMAcosta/Twitter-s-customer-service-threads-analysis/blob/main/Twitter's_customer_service_threads_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# objetivo: detectar partes de conversaciones en redes sociales (twitter o reddit) en las que las intervenciones están en una estructura conversacional argumentativa, es decir, una contesta a la otra, o elabora el tema presentado, no son inconexas.
#
# - buscar un dataset
# - pensar qué características podrían ser indicativas de coherencia: semejanza entre las intervenciones (hablan del mismo tema), uso de conectores,
# - aplicar aproximación de autoaprendizaje y descubrir nuevas características útiles para identificar coherencia

# %% [markdown]
# dataset:
# https://www.kaggle.com/thoughtvector/customer-support-on-twitter

# %%
# !pip install -U spacy==3.1.2
# !pip install umap-learn
# !python -m spacy download es_core_news_md
# Out:
# Requirement already satisfied: spacy==3.1.2 in /usr/local/lib/python3.7/dist-packages (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (3.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (8.0.11)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (1.19.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (2.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (21.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (0.6.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (4.62.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.2) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy==3.1.2) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy==3.1.2) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy==3.1.2) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.2) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.2) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy==3.1.2) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy==3.1.2) (2.0.1)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.5.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.19.5)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.22.2.post1)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.0.1)
# Collecting es-core-news-md==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.1.0/es_core_news_md-3.1.0-py3-none-any.whl (42.7 MB)
#      |████████████████████████████████| 42.7 MB 38 kB/s
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from es-core-news-md==3.1.0) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (4.62.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.7.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.19.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (21.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (8.0.11)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2021.5.30)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %%
import json
import pandas as pd
import numpy as np
from google.colab import drive
from tqdm.notebook import tqdm

from collections import defaultdict

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATASET_PATH = "/content/drive/MyDrive/facu/textmining/"
DATASET_NAME = "twcs.csv"
MAX_ROWS = 1000000
THRESHOLD_THREADS = 10

df = pd.read_csv(DATASET_PATH + DATASET_NAME, nrows=MAX_ROWS)   
df
# Out:
#         tweet_id   author_id  ...        response_tweet_id in_response_to_tweet_id
# 0              1  sprintcare  ...                        2                     3.0
# 1              2      115712  ...                      NaN                     1.0
# 2              3      115712  ...                        1                     4.0
# 3              4  sprintcare  ...                        3                     5.0
# 4              5      115712  ...                        4                     6.0
# ...          ...         ...  ...                      ...                     ...
# 999995   1108226  AmazonHelp  ...                      NaN               1108224.0
# 999996   1108227  AmazonHelp  ...          1108228,1108229               1108224.0
# 999997   1108228      381550  ...                  1108230               1108227.0
# 999998   1108230  AmazonHelp  ...                      NaN               1108228.0
# 999999   1108229      381551  ...  1108231,1108232,1108233               1108227.0
#
# [1000000 rows x 7 columns]

# %%
# Preprocess csv
df.set_index("tweet_id", inplace = True)
df.in_response_to_tweet_id = df.in_response_to_tweet_id.astype("Int64")
df
# Out:
#            author_id  inbound  ...        response_tweet_id in_response_to_tweet_id
# tweet_id                       ...
# 1         sprintcare    False  ...                        2                       3
# 2             115712     True  ...                      NaN                       1
# 3             115712     True  ...                        1                       4
# 4         sprintcare    False  ...                        3                       5
# 5             115712     True  ...                        4                       6
# ...              ...      ...  ...                      ...                     ...
# 1108226   AmazonHelp    False  ...                      NaN                 1108224
# 1108227   AmazonHelp    False  ...          1108228,1108229                 1108224
# 1108228       381550     True  ...                  1108230                 1108227
# 1108230   AmazonHelp    False  ...                      NaN                 1108228
# 1108229       381551     True  ...  1108231,1108232,1108233                 1108227
#
# [1000000 rows x 6 columns]

# %%
tweets_ids = set(df.index)
roots = set(df[df["in_response_to_tweet_id"].isnull()].index)
leafs = set(df[df["response_tweet_id"].isnull()].index)

# %%
print(len(leafs), len(roots), len(tweets_ids))
# Out:
# 347194 267691 1000000

# %%
def dfs_tweets(tweet_id, threads, thread):
    if tweet_id not in tweets_ids:
        # If any tweet in the middle betweet root and leaf, isn't in the 
        # Data Frame, ignore thread
        return

    thread.append(tweet_id)
    if tweet_id in roots:
        # If the tweet is a root, append the entire thread reversed
        threads.append(thread[::-1])
    else:
        parent = df.loc[tweet_id]["in_response_to_tweet_id"]
        dfs_tweets(parent, threads, thread)

# %%
# Build Threads

threads = []
for leaf in tqdm(leafs):
    dfs_tweets(leaf, threads, [])
# Out:
#   0%|          | 0/347194 [00:00<?, ?it/s]

# %%
# Show firsts 10 threads
for thread in threads[:10]:
    for i, tweet_id in enumerate(thread):
        print("(@" + df.loc[tweet_id]["author_id"] + ")", df.loc[tweet_id]["text"])
    print("---------------------------------")
# Out:
# (@367816) It's a shock if 24 hrs later @safaricom_care, cannot be able to top up a scratch card for me even after giving them serial number 3times.
# (@Safaricom_Care) @367816 Hello, share the voucher serial number, amount and your mobile number via DM we check and advise. ^WN
# (@367816) @Safaricom_Care Have asked what's the lead time of topping up a scratch card thru' availing serial number and your team ain't responding @119433!
# (@Safaricom_Care) @367816 @119433 Hi, we are unable to top up due to a slight system issue, we will get back to you soonest. Apologies. ^KD
# (@367816) @Safaricom_Care @119433 An issue raised yesterday @ 8am and hasn't been resolved over 24hrs later you underplay that as a "slight system issue" ? ? Jokers!
# (@Safaricom_Care) @367816 @119433 As per our conversation, we are dealing with your issue on ticket number 1-D8B011A. We will get back to you. ^KD
# (@367816) @Safaricom_Care @119433 Let me know the outcome of the ticket raised last Friday!
# (@Safaricom_Care) @367816 @119433 Good morning Enock, we apologize for the delay. Card has been topped up please discard it and confirm your airtime balance. ^MA
# (@367816) @Safaricom_Care @119433 Airtime received, but am shocked by the slow working process from your end. It has taken 120 hrs to recharge a airtime!
# (@Safaricom_Care) @367816 @119433 Apologies Enock. ^MA
# ---------------------------------
# (@115721) @115722 tried to pay a bill for 60 days. No service, rude CS, and several transfers. Look up my equipment # and give me an acct #!
# (@115722) @115721 Are you referring to wireless or residential service?
# ^JAY
# (@115721) @115722 Nobody can find my account or number. I walked out of a store with this. I've explained that they can find my acct via my devices serial #..
# (@115722) @115721 Hello Duke, Do you have a copy of your bill? What state are your services located in?
# ^NHP
# (@115721) @115722 MD. And this was sent to the wrong address https://t.co/dMQ1WZXJOk
# (@VerizonSupport) @115721 Please follow and DM us so that we can look into this order.
# ^HSB
# (@115721) @VerizonSupport What else can I provide? They refuse to help me because they cannot validate the account...
# (@VerizonSupport) @115721 We would not be able to verify anything without authenticating your account.
# ^JAY
# (@115721) @VerizonSupport How? I have my phone number and email, that's it. How did I get equipment and service? I'm literally trying to pay and nobody can find me?
# (@VerizonSupport) @115721 We can use the order number to locate the account but will need to do so in our secure one on one chat. Please follow and DM us.
# ^HSB
# ---------------------------------
# (@115723) @115722 is the worst ISP I’ve ever had
# (@VerizonSupport) @115723 What did we do to make you feel this way and how can we fix things between us? ^KMG
# (@115723) @VerizonSupport Cuts out every 20 minutes this is ridiculous
# (@VerizonSupport) @115723 Are all your services cutting out?
# ^ACM
# (@115723) @VerizonSupport Yep
# (@VerizonSupport) @115723 Do you have our Fios service?  When services go out, does the internet light on the router change color? ^BCW
# (@115723) @VerizonSupport Just randomly boots me offline there it goes again
# (@VerizonSupport) @115723 Did the lights change on the router when this happened?
# ^JAY
# (@115723) @VerizonSupport Don’t know, router is downstairs. But it’s just the WiFi Nothing connected to Ethernet
# (@VerizonSupport) @115723 Is the light on top red?
# ^JAY
# ---------------------------------
# (@115762) @ATVIAssist i pre ordered wwii but how do i get the code?
# (@115762) @ATVIAssist For double xp^
# (@ATVIAssist) @115762 Hello there, I apologize for the delay. Can you clarify where you pre-ordered the game? Please be sure you keep us updated. ^RN
# (@115762) @ATVIAssist I pre ordered my game at game stop
# (@ATVIAssist) @115762 Hey there! You can check out this link for more information in regards to this - https://t.co/OZIlONCLtF ^KO
# (@115762) @ATVIAssist So, when I go get the game on friday my 2xp code will be on the receipt?
# (@ATVIAssist) @115762 Did gamestop give you a code with your pre order down payment that you needed to redeem? ^KO
# (@115762) @ATVIAssist Yes, the beta code
# (@ATVIAssist) @115762 Have you redeemed that on your https://t.co/4YBn633EOk account? Even tho it says beta code, your pre order bonus are linked. ^KO
# (@115762) @ATVIAssist Yes I have, so my code is on their?
# ---------------------------------
# (@115768) @115769 whats going on with your app. its totally stuck here for 1 hour and prior to updating froze and didnt work since updating. https://t.co/UpoCzPNqFb
# (@AdobeCare) @115768 Hi Jeffrey, were you able to update to Lightroom Classic CC?   ^Tanuj
# (@115768) @AdobeCare nope still down.
# (@AdobeCare) @115768 Have you tried signing out/back in or reinstalling the CC desktop app? https://t.co/Ne2f7tDTM0 Let us know! ^Madison
# (@115768) @AdobeCare yes ive done that multiple times. its happened on previous versions as well.
# (@AdobeCare) @115768 Thanks for confirming. We're looping in an expert who can help you out here. They will reply as soon as they're available. ^Madison
# (@115768) @AdobeCare so..when are they available?
# (@AdobeCare) @115768 Sorry for this. Let me request the expert to look into this ASAP as he is in office. ^Raj
# (@115768) @AdobeCare ok. its been very frustrating. i have multiple jobs that i need finished and your application isnt helping.
# (@AdobeCare) @115768 Hi Jeffrey, we wanted to check if you had managed to install Lightroom Classic CC. Please let us know if you need further assistance. ^NR https://t.co/iuwZCjz4Or
# (@115768) @AdobeCare no its still broken. i deleted it and will probably be getting rid of my membership and return when its working properly. thanks
# (@AdobeCare) @115768 Jeffrey did you use the process listed in https://t.co/ccvXXUvXuT to delete Lightroom Classic CC? ^Jeff
# (@115768) @AdobeCare yea ive done everything you guys told me to do. i know its not my mac either as i have the retina imac which is fairly new.
# ---------------------------------
# (@115768) @115769 whats going on with your app. its totally stuck here for 1 hour and prior to updating froze and didnt work since updating. https://t.co/UpoCzPNqFb
# (@AdobeCare) @115768 Hi Jeffrey, were you able to update to Lightroom Classic CC?   ^Tanuj
# (@115768) @AdobeCare nope still down.
# (@AdobeCare) @115768 Have you tried signing out/back in or reinstalling the CC desktop app? https://t.co/Ne2f7tDTM0 Let us know! ^Madison
# (@115768) @AdobeCare yes ive done that multiple times. its happened on previous versions as well.
# (@AdobeCare) @115768 Thanks for confirming. We're looping in an expert who can help you out here. They will reply as soon as they're available. ^Madison
# (@115768) @AdobeCare so..when are they available?
# (@AdobeCare) @115768 Sorry for this. Let me request the expert to look into this ASAP as he is in office. ^Raj
# (@115768) @AdobeCare ok. its been very frustrating. i have multiple jobs that i need finished and your application isnt helping.
# (@AdobeCare) @115768 Hi Jeffrey, we wanted to check if you had managed to install Lightroom Classic CC. Please let us know if you need further assistance. ^NR https://t.co/iuwZCjz4Or
# (@115768) @AdobeCare no its still broken. i deleted it and will probably be getting rid of my membership and return when its working properly. thanks
# (@AdobeCare) @115768 Jeffrey did you use the process listed in https://t.co/ccvXXUvXuT to delete Lightroom Classic CC? ^Jeff
# (@115768) @AdobeCare ill just wait for the next big update. ive wasted my time and patience with adobe products
# (@AdobeCare) @115768 Jeffrey I am sorry to hear that. If you face future errors please review the installation logs. https://t.co/okPwBIqSxR ^Jeff
# ---------------------------------
# (@115768) @115769 whats going on with your app. its totally stuck here for 1 hour and prior to updating froze and didnt work since updating. https://t.co/UpoCzPNqFb
# (@AdobeCare) @115768 Hi Jeffrey, were you able to update to Lightroom Classic CC?   ^Tanuj
# (@115768) @AdobeCare nope still down.
# (@AdobeCare) @115768 Have you tried signing out/back in or reinstalling the CC desktop app? https://t.co/Ne2f7tDTM0 Let us know! ^Madison
# (@115768) @AdobeCare yes ive done that multiple times. its happened on previous versions as well.
# (@AdobeCare) @115768 Thanks for confirming. We're looping in an expert who can help you out here. They will reply as soon as they're available. ^Madison
# (@115768) @AdobeCare so..when are they available?
# (@AdobeCare) @115768 Sorry for this. Let me request the expert to look into this ASAP as he is in office. ^Raj
# (@115768) @AdobeCare ok. its been very frustrating. i have multiple jobs that i need finished and your application isnt helping.
# (@AdobeCare) @115768 Hi Jeffrey, we wanted to check if you had managed to install Lightroom Classic CC. Please let us know if you need further assistance. ^NR https://t.co/iuwZCjz4Or
# (@115768) @AdobeCare no its still broken. i deleted it and will probably be getting rid of my membership and return when its working properly. thanks
# (@AdobeCare) @115768 Hi there, I am looping our expert team to help answer your question. Thanks! ^MC
# (@115768) @AdobeCare you guys have been saying that for weeks now. your product went from being great to now unable to work and terrible. very disappointed.
# ---------------------------------
# (@115798) Lost your booking number? No worries, just drop me the passenger's name, flight details and email. I'll trace it and email u in no time :)
# (@115797) @AirAsiaSupport lost my booking # chua loreen lee flight z2 129.128 12/22-01/8 taipei-manila. __email__
# (@AirAsiaSupport) @115797 Sorry as we checked booking has already expired due to no payment made. Kindly please proceed with new booking - Ed
# (@115797) @AirAsiaSupport hi!  I have booked my ticket and when i see my itenary has been redundant i call ur customer service to assist but out of line.
# (@AirAsiaSupport) @115797 Hi Loreen,kindly DM us your booking number and attach guest passport copy, we'll fix it for you, see you there!- Anwar
# (@115797) @AirAsiaSupport Hi! I have DM u my booking # and passport picture thanks so much for quick action
# (@AirAsiaSupport) @115797 Hi Loreen,correction done! :) See you on board! Cheers!- Anwar
# (@115797) @AirAsiaSupport Hi! i would like to know on my itenerary on how the birthday can be seen. i would like to double check if i can key in our birthdays right 🙂
# (@AirAsiaSupport) @115797 Hi Loreen, you may check the passenger's date of birth via AirAsia member account under manage booking. Thanks-Sha
# (@115797) @AirAsiaSupport but i cant see it. i only see itenerary.. no birthday
# (@AirAsiaSupport) @115797 As you may check it under manage my booking online or during web check in. Date of birth will be shown accordingly.- Ed
# (@115797) @AirAsiaSupport Hi Airasia. i want to rebook my return flight. but when i try rebooking my inbond also is rebooking. please help me. thanks
# (@AirAsiaSupport) @115797 Hi Loreen :) Kindly DM us the booking number that you wish to do change flight for us to assist you further-Thanks-Anwar
# ---------------------------------
# (@115807) @AskAmex Thought Amex values their customers. But boy you got really bad reps on the customer service.
# (@AskAmex) @115807 Hi there, I am so sorry to her that. what exactly is the issue you are having?
# (@115807) @AskAmex Nope. They weren’t ready to listen what I wanted to say and if I had any questions about anything else and hung up on me.
# (@AskAmex) @115807 I am so sorry to hear that. Which U.S. based card do you have? Pls do not share any personal info.
# (@115807) @AskAmex Amex Platinum and Amex everyday card.
# (@AskAmex) @115807 What exactly is the issue you are having?
# (@115807) @AskAmex I’ve asked your sales rep about the payments and she wasn’t ready to listen to any issues that I had.
# (@AskAmex) @115807 Apologies for all of the issues. If you have time to chat securely with me, I would be happy to review. ^Rachel
# (@115807) @AskAmex Sure. Please drop me a message now.
# (@AskAmex) @115807 Great. Please go to https://t.co/crJMnNwi0H log in and select code 10307  and we will continue our conversation there. ^RK
# ---------------------------------
# (@367994) Getting mixed messages from my foil. Which one is it @marksandspencer? https://t.co/OiezKFFMlq
# (@367994) @marksandspencer @361794 can you shed any light on this? Marks' usually so on point with the packaging.
# (@361794) @367994 @marksandspencer Is it just a serving suggestion? For example; Barry Scott doesn't really have a Cilit Bang based car etc?
# (@367994) @361794 @marksandspencer But it forbids contact with citrus fruits whilst displaying a lemon on the packaging?
# (@361794) @367994 @marksandspencer I didn't design this packaging.
# (@367994) @361794 @marksandspencer My mistake. Apologies.
# (@361794) @367994 @marksandspencer  https://t.co/b3lLS7Py5k
# (@367994) @361794 @marksandspencer I know what you mean! I also miss the verve and tenacity of mid noughties M&amp;S food packaging. A bit like Mourinho's style of play!
# (@361794) @367994 @marksandspencer I hope they respond about this citrus fruit dilemma.
# (@367994) @361794 @marksandspencer It'll sure be detrimental to my NPS if they don't (never mind the tastiness of my fish dishes 😉)
# (@marksandspencer) @367994 Hi Nathaniel, can you let us know what the packaging is for? Barcode would be great as well :)
# (@367994) @marksandspencer  https://t.co/u1y5HLjTRN
# (@marksandspencer) @367994 Thanks Nathaniel, we've fed this back to our Food Team to review the packaging in the near future and appreciate you flagging it with us.
# ---------------------------------

# %%
# Filter threads with less than `THRESHOLD_THREADS` tweets
print(len(threads))
threads = list(filter(lambda thread: len(thread) >= THRESHOLD_THREADS, threads))
print(len(threads))
# Out:
# 345271
# 12161
